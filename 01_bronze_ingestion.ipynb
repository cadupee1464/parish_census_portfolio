# %%
# %pip install openpyxl
# %restart_python

# %%
import os
import pandas as pd

# %%
file_path = '/Volumes/workspace/default/parish_data/Portfolio_Parish_Census.xlsx'
persons_pd = pd.read_excel(file_path, sheet_name='Persons')
households_pd = pd.read_excel(file_path, sheet_name='Households')

# %%
persons_df = spark.createDataFrame(persons_pd)
household_df = spark.createDataFrame(households_pd)

# %%
(
    persons_df.write
    .format('delta')
    .mode('overwrite')
    .saveAsTable('workspace.default.bronze_persons')
)

(
    household_df.write
    .format('delta')
    .mode('overwrite')
    .saveAsTable('workspace.default.bronze_households')
)
