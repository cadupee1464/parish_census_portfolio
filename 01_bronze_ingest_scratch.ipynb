# %% [markdown]
# # GIT TEST!!!!

# %%
# %pip install openpyxl

# %%
# %restart_python

# %%
import os
import pandas as pd

# %%
file_path = '/Volumes/workspace/default/parish_data/Portfolio_Parish_Census.xlsx'

os.path.exists(file_path)

# %%
xls = pd.ExcelFile(file_path)

xls.sheet_names

# %%
households = pd.read_excel(file_path, sheet_name='Households')
print(households.head(5))
households.columns

# %%
persons = pd.read_excel(file_path, sheet_name='Persons')
print(persons.head(5))

# %%
household_df = spark.createDataFrame(households)
persons_df = spark.createDataFrame(persons)

# %%
display(household_df)

# %%
household_df.printSchema()
